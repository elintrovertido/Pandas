# %% [markdown]
# <a href="https://colab.research.google.com/github/elintrovertido/Pandas/blob/main/ten_10_pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
>>> df = pd.DataFrame([[1, 2, 3],
...                    [4, 5, 6],
...                    [7, 8, 9],
...                    [np.nan, np.nan, np.nan]],
...                   columns=['A', 'B', 'C'])

# df.agg(['sum', 'min','max'], axis = 'columns')
df.agg(
    {
        'A' : ['sum', 'min','max'],
        'B' : ['sum', 'max', 'mean']
    })
# Out:
#          A     B
# sum   12.0  15.0
# min    1.0   NaN
# max    7.0   8.0
# mean   NaN   5.0

# %%
df.agg( minimum_in_A = ('A' , 'min'))
# Out:
#                 A
# minimum_in_A  1.0

# %%
# df.transform(lambda x : x +1 )

# def add_five(x):
#     return x + 5
# df.transform(lambda x : add_five(x))

# df.transform([lambda x : x ** 2 ])

# df.transform({
#     'A' : lambda x : x + 1,
#     'B' : lambda x : x * 2,
#     'C' : lambda x : x ** 2
# })
# Out:
#      A     B     C
# 0  2.0   4.0   9.0
# 1  5.0  10.0  36.0
# 2  8.0  16.0  81.0
# 3  NaN   NaN   NaN

# %%
series = pd.Series(np.random.randint(0,5, size = 10))
series
# Out:
# 0    4
# 1    3
# 2    2
# 3    4
# 4    3
# 5    3
# 6    4
# 7    1
# 8    1
# 9    0
# dtype: int64

# %%
series.value_counts(normalize = True)
# Out:
# 4    0.3
# 3    0.3
# 1    0.2
# 2    0.1
# 0    0.1
# Name: proportion, dtype: float64

# %%
s = pd.Series(["A", "B", "C", "Aaba", "Baca", np.nan, "CABA", "dog", "cat"])

s = s.str.lower()
s
# Out:
# 0       a
# 1       b
# 2       c
# 3    aaba
# 4    baca
# 5     NaN
# 6    caba
# 7     dog
# 8     cat
# dtype: object

# %%
left = pd.DataFrame({"key": ["foo", "bar"], "lval": [1, 2]})
right = pd.DataFrame({'key' : ["foo", "bar"] , "rval": [4, 5]})
print(left)
print(right)

result = pd.merge(left, right, on = 'key')
result
# Out:
#    key  lval
# 0  foo     1
# 1  bar     2
#    key  rval
# 0  foo     4
# 1  bar     5
#    key  lval  rval
# 0  foo     1     4
# 1  bar     2     5
