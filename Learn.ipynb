# %% [markdown]
# <a href="https://colab.research.google.com/github/elintrovertido/Pandas/blob/main/Learn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # **Data Structures**

# %% [markdown]
# # Essential basic functionality

# %%
In [1]: index = pd.date_range("1/1/2000", periods=8)

In [2]: s = pd.Series(np.random.randn(5), index=["a", "b", "c", "d", "e"])

In [3]: df = pd.DataFrame(np.random.randn(8, 3), index=index, columns=["A", "B", "C"])

# %%
df.columns = [x.lower() for x in df.columns]
df
# Out:
#                    a         b         c
# 2000-01-01  0.494547  0.996572  1.144017
# 2000-01-02 -1.174379 -0.270489  1.324798
# 2000-01-03  0.493987  0.612873 -1.096421
# 2000-01-04  0.724730 -0.912875 -0.248726
# 2000-01-05  1.859507  0.203581 -0.270371
# 2000-01-06 -1.771752  0.539733 -1.258367
# 2000-01-07 -1.924899  0.300239  0.721684
# 2000-01-08 -0.524956 -0.604988 -0.748857

# %%
print(s.array)
print(s.index.array)
# Out:
# <PandasArray>
# [ 0.4434953700130492, 0.34784175234145487,   1.315100500936612,
#  0.20033802486076654,  0.8710392785654552]
# Length: 5, dtype: float64
# <PandasArray>
# ['a', 'b', 'c', 'd', 'e']
# Length: 5, dtype: object

# %%
df.to_numpy()
# Out:
# array([[ 0.20412288,  0.6644061 ,  1.49128487],
#        [ 0.52246807, -0.46833745,  0.53424693],
#        [ 1.45197248, -1.66016555, -0.31560874],
#        [ 1.55156802, -1.35937086,  0.32930895],
#        [ 1.66262391,  1.54166472,  0.1324465 ],
#        [ 0.32757475,  0.63376295,  2.51409688],
#        [ 0.26400417,  0.749786  ,  1.03734807],
#        [ 0.20185295, -1.19476823,  0.4839539 ]])

# %%
df > 0
# Out:
#                A      B      C
# 2000-01-01  True   True   True
# 2000-01-02  True  False   True
# 2000-01-03  True  False  False
# 2000-01-04  True  False   True
# 2000-01-05  True   True   True
# 2000-01-06  True   True   True
# 2000-01-07  True   True   True
# 2000-01-08  True  False   True

# %%
np.nan == np.nan
# Out:
# False

# %%
df1 = pd.DataFrame({"col": ["foo", 0, np.nan]})
df2 = pd.DataFrame({"col": [np.nan, 0, "foo"]}, index=[2, 1, 0])
# print(df1)
# print(df2)
df1.equals(df2)
# Out:
# False

# %%
index = ['student1' , 'student2' , 'student3']
df = pd.DataFrame({
    'm' : [1,2,3],
    'p' : [4,5,6],
    'c' : [7,8,9],
} , index = index)

df.sum(axis = 'index', level = 0)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-36-406c817f2c64> in <cell line: 8>()
#       6 } , index = index)
#       7
# ----> 8 df.sum(axis = 'index', level = 0)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in sum(self, axis, skipna, numeric_only, min_count, **kwargs)
#   11510             **kwargs,
#   11511         ):
# > 11512             return NDFrame.sum(self, axis, skipna, numeric_only, min_count, **kwargs)
#   11513
#   11514         setattr(cls, "sum", sum)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in sum(self, axis, skipna, numeric_only, min_count, **kwargs)
#   11278         **kwargs,
#   11279     ):
# > 11280         return self._min_count_stat_function(
#   11281             "sum", nanops.nansum, axis, skipna, numeric_only, min_count, **kwargs
#   11282         )
#
# ...

# %%
df = pd.DataFrame({
    'A': [1, 2, None],
    'B': [4, None, 6]
})

# df.sum(axis = 'index' , skipna = True)
# df.sum(axis = 'columns', skipna = True)
# df.sum(0, level = 'A')
# df.cumsum(0)
# df.nunique()
# df.describe(percentiles = [.01,.02,.03, 0.04,.5,.10])
# df.idxmin()
# df.idxmax()
# x = df.idxmin(numeric_only=bool, axis = 1)
# for idx,i in enumerate(x):
#     print(idx,i)
# Out:
# 0 A
# 1 A
# 2 B

# %%
df = pd.DataFrame({
    'A': [1, 2, 3],
    'B': [4, 5, 6]
}, index = ['a' , 'b' , 'c'])

# def add_df(series):
#     for x in series:
#         print(x, end= ' & ')
#     print()

# print(df)
# df.apply(lambda x : add_df(x))
# print(df)
# df.apply(lambda x : x.sum(), axis = 'columns')

print(df)
df.applymap(lambda x : x + 1)
# Out:
#    A  B
# a  1  4
# b  2  5
# c  3  6
#    A  B
# a  2  5
# b  3  6
# c  4  7
